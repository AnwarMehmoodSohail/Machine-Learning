# %%
from openai import OpenAI

# Initialize the OpenAI client with OpenRouter as the backend.
# NOTE: Replace the API key below with YOUR OWN key obtained from OpenRouter.
client = OpenAI(
    base_url="https://openrouter.ai/api/v1",
    api_key="API-KEY",
)

# %%
# Function to create a chatbot using an LLM
def chatbot():
    print("Chatbot (type 'exit' to quit):")
    while True:
        user_input = input("You: ")
        if user_input.lower() in ["exit", "quit"]:
            print("Chatbot: Goodbye!")
            break

        # Prepare messages for the LLM
        messages = [
            {"role": "system", "content": """
                You are a friendly chatbot assistant.
                Your task is to have a natural, helpful, and polite conversation with the user.
                Respond concisely and clearly.
            """},
            {"role": "user", "content": user_input}
        ]

        # Call the model through OpenRouter (model = "gpt-oss-20b")
        response = client.chat.completions.create(
            model="gpt-oss-20b",
            messages=messages,
        )
        
        # Extract and clean the model's output
        bot_reply = response.choices[0].message.content.strip()
        # Print the used input
        print("User:", user_input)
        # Print the Chatbot reply
        print("Chatbot:", bot_reply)

# Start the chatbot
chatbot()
# Out:
# Chatbot (type 'exit' to quit):
# User: hi
# Chatbot: Hey there! How can I help you today? 😄
# User: how are you
# Chatbot: I'm doing great, thanks! How can I help you today?
# User: nothing
# Chatbot: I’m here if you need anything. Just let me know what you’d like to talk about or if you have any questions!
# User: no question
# Chatbot: Sure! If anything comes up or you just want to chat, feel free to let me know.
# User: ok
# Chatbot: Sure thing! How can I assist you today?
# User: ok
# Chatbot: Sure thing! How can I help you today?
# Chatbot: Goodbye!

# %%
# Out:
# Chatbot (type 'exit' to quit):
# Chatbot: Hi there! How can I help you today?
# Chatbot: Hello! How can I help you today?
# Chatbot: Goodbye!
